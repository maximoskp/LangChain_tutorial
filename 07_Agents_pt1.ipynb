# %%
from langchain_ollama import ChatOllama

# Initialize the ChatOllama model with the specified model name
model_name = 'qwen2.5:3b'

# and initialize the ChatOllama instance
chat_model = ChatOllama(
    model=model_name,
    validate_model_on_init=True,
    temperature=0.0
)

# %%
response = chat_model.invoke("How much is 15 times 32 to the power of 2?")
print(response)
# Out:
# content="To solve this problem, we need to calculate \\(15 \\times (32^2)\\).\n\nFirst, let's find \\(32^2\\):\n\n\\[ 32^2 = 32 \\times 32 \\]\n\nCalculating this:\n\n\\[ 32 \\times 32 = 1024 \\]\n\nNow we have to multiply the result by 15:\n\n\\[ 15 \\times 1024 \\]\n\nLet's do the multiplication:\n\n\\[ 15 \\times 1024 = 15360 \\]\n\nSo, \\(15 \\times (32^2) = 15360\\)." additional_kwargs={} response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-02-02T05:11:55.562888872Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2190017373, 'load_duration': 89342078, 'prompt_eval_count': 46, 'prompt_eval_duration': 25811476, 'eval_count': 145, 'eval_duration': 1828030777, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'} id='lc_run--019c1cc3-b31b-71c2-a8f4-c6d624d2728c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 46, 'output_tokens': 145, 'total_tokens': 191}
