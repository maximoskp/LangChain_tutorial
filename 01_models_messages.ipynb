# %% [markdown]
# # Overview
#
# This tutorial is about loading an Ollama model and interacting with it. This interaction includes messages. The tutorial ends by makeing a simple chat application that keeps chat history.

# %% [markdown]
# # Load a chat model
#
# Chat models can generate text by continuing a given prompt. First we need to load a model that has been pulled via Ollama (see README.md for details).

# %%
from langchain_ollama import ChatOllama

# %%
# Initialize the ChatOllama model with the specified model name
model_name = 'qwen3-vl:4b'

# and initialize the ChatOllama instance
chat_model = ChatOllama(
    model=model_name,
    validate_model_on_init=True,
    temperature=0.7
)

# %% [markdown]
# ## Model invocation
#
# We can invoke a model, i.e., give it a prompt to generate output, either by passing a string of the prompt, or by providing messages. Messages are either in the form of dictionaries or special LangChain classes

# %% [markdown]
# ### Invocation with direct text
#
# We can invoke the message with a simple string that includes the prompt.

# %%
# Invoke model with string input
response = chat_model.invoke("How can I make a delicious chocolate cake?")

# %%
# The response is an AIMessage object that includes the model's reply
print(type(response))

# We can get the content of the response like this
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# Making a **delicious, moist, and perfectly baked chocolate cake** is all about balancing the right ingredients, technique, and timing. Here’s a **tested, reliable recipe** (with *why* each step matters) that’s beginner-friendly and guaranteed to impress—no fancy tools needed!
#
# ---
#
# ### 🍫 **The Ultimate Chocolate Cake Recipe**
# *(Serves 8–10 | Prep: 25 mins | Bake: 35–40 mins)*
#
# #### **Why This Works**
# - **High-quality chocolate** (semi-sweet or dark, 60–70% cacao) adds depth.
# - **Room temperature ingredients** = smoother batter, better texture.
# - **No overmixing** = tender crumb (overmixing = tough cake).
# - **Butter + sugar creaming** = air pockets for lightness.
# - **Baking powder/salt** = balanced rise and flavor.
#
# ---
#
# ### 📋 **Ingredients**
# *(Adjust for dietary needs: see "Pro Tips" below)*
#
# | **Ingredient** | **Amount** | **Why?** |
# |----------------|------------|----------|
# | **Butter** (unsalted) | 1 cup (225g) | *Room temp = melts evenly, no lumps.* |
# | **Granulated sugar** | 1.5 cups (350g) | *More sugar = richer flavor + moisture. Use brown sugar for caramel notes.* |
# | **All-purpose flour** | 1.5 cups (225g) | *Not cake flour—more structure (but not too dense).* |
# | **Baking powder** | 1.5 tsp | *Essential for rise (don’t skip!)* |
# | **Salt** | 1/2 tsp | *Balances sweetness, prevents blandness.* |
# | **Semi-sweet chocolate** (or dark 60–70% cacao) | 1.5 cups (375g) | *Use high-quality, chopped or melted (see note!)* |
# | **Eggs** | 2 large | *Room temp = easier to mix in.* |
# | **Vanilla extract** | 2 tsp | *Adds complexity—use pure vanilla.* |
# | **Milk** | 1 cup (240ml) | *Whole milk = richer flavor.* |
# | **Butter** (for greasing pan) | 1 tbsp | *Prevent sticking.* |
#
# > **Pro Tip:**
# > - **Chocolate Choice:** Use **semi-sweet** (like Ghirardelli 60% cacao) for a classic balance. If using **dark chocolate**, reduce sugar by 2 tbsp (or add 1 tbsp of milk to compensate).
# > - **Melted Chocolate:** Melt chocolate *just* until smooth (not boiling), then stir in 1 tbsp of butter. *Do not skip this step—melted chocolate ensures no gritty bits!*
# > - **Flour:** Sift flour *with baking powder/salt* first (prevents clumps).
#
# ---
#
# ### 🥣 **Step-by-Step Instructions**
# *(Follow exactly—no shortcuts!)*
#
# #### **1. Prep the Pan**
# - Grease a 9x13 inch (or 8-inch round) pan with butter or non-stick spray. Dust with flour.
# - *Why?* Prevents sticking and ensures even baking.
#
# #### **2. Cream Butter & Sugar**
# - In a large bowl, beat **buttermelted butter** and **sugar** on medium speed for 3–5 minutes until **light and fluffy**.
# - *Why?* This incorporates air—crucial for a *light* cake (don’t skip!).
#
# #### **3. Mix in Dry Ingredients**
# - **Sift flour, baking powder, and salt** together (no lumps).
# - **Add to butter-sugar mixture** in 3 parts, mixing just until combined (don’t overmix—just 20–30 seconds).
# - *Why?* Overmixing = tough cake. Sifting ensures even distribution.
#
# #### **4. Add Wet Ingredients**
# - **Beat eggs** (room temp) until smooth.
# - **Add vanilla** and **milk** to butter-sugar mixture.
# - **Gently fold in melted chocolate** (stir until smooth—no lumps!).
# - **Add flour mixture** to wet ingredients in 3 parts, folding *just* until no dry streaks.
# - *Why?* Gentle folding = tender crumb (don’t stir too long).
#
# #### **5. Bake**
# - **Pour batter** into pan, smooth top.
# - **Bake at 350°F (175°C)** for **35–40 mins** (or until a toothpick comes out clean).
# - *Why?* Oven temps vary—check at 35 mins. *Do not open the oven* (heat escapes = uneven baking).
#
# #### **6. Cool & Frost**
# - **Cool 1 hour** in pan (don’t rush—frosting too soon = messy).
# - **Frost** with chocolate ganache, buttercream, or simple powdered sugar.
# - *Why?* Cooling ensures the cake sets, and frosting adheres.
#
# ---
#
# ### ⚠️ **Common Pitfalls & Fixes**
# | **Problem** | **Fix** |
# |-------------|---------|
# | **Dry cake** | Underbaked? → Check oven temp (it’s often 25°F too high). |
# | **Soggy bottom** | Pan not greased well? → Use parchment paper or oil the pan. |
# | **Not rising** | Baking powder expired? → Replace with fresh powder (saves the cake!). |
# | **Grainy texture** | Chocolate not melted? → Melt chocolate *slowly* over low heat. |
# | **Overbaked** | Toothpick not clean? → Check at 35 mins (some ovens bake faster). |
#
# ---
#
# ### ✨ **Pro Tips for Perfection**
# - **Use a kitchen scale** for accuracy (1 cup = 225g).
# - **Don’t skip the creaming step**—it’s why your cake isn’t dense.
# - **Frost after cooling completely** (if you rush, the cake melts).
# - **For extra richness:** Add 2 tbsp of **milk** or **cream** to the batter.
# - **For a chocolatey twist:** Mix in 1 tbsp of **cocoa powder** (not chocolate) with the dry ingredients.
#
# ---
#
# ### 🎂 **Final Word**
# This recipe is **tested, reliable, and forgiving**—even if you’re a beginner. The key is **room temperature ingredients**, **no overmixing**, and **baking at 350°F**. With these steps, you’ll have a **moist, rich cake** that’s the best of all kinds.
#
# > *“The best chocolate cake is one that’s so good, you forget it’s just cake.”*
# > — *Chef’s note: Always let it cool—don’t skip this step, or your cake will fall apart when you try to frost it!*
#
# Let me know how it turns out! 😊 **Want a vegan or gluten-free version?** I can adapt this too.

# %% [markdown]
# ### Invocation with LangChain messages
#
# We can invoke a message with LangChain messages. These messages are objects of classes, like the `AIMessage`, that are intepreted by models as having different roles within the chat, affecting how the model parses them differently.
#
# Along with the `AIMessage` class, there is a `SystemMessage` and a `HumanMessage class`. There is also a `TollMessage` class, but we will see it in a next tutorial.
#
# - `SystemMessage` - Tells the model how to behave and provide context for interactions.
# - `HumanMessage` - Represents user input and interactions with the model.
# - `AIMessage` - Responses generated by the model, including text content, tool calls, and metadata.
# - `ToolMessge` - Represents the outputs of tool calls (next tutorial).
#
# For more information on messages you can visit: https://docs.langchain.com/oss/python/langchain/messages#tool-message

# %%
# Let's initialize a system message and a human message
from langchain.messages import SystemMessage, HumanMessage
system_message = SystemMessage(content="You are a helpful assistant that provides cooking tips.")
human_message = HumanMessage(content="Can you suggest a recipe for chocolate cake?")

messages = [system_message, human_message]

# Now, we can pass these messages to the chat model
response = chat_model.invoke(messages)

# %%
# The response is again an AIMessage object
print(type(response))

# And we can print the content of the response
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# Absolutely! Here's a **classic, foolproof chocolate cake recipe** with tips for perfect texture and flavor. It’s simple, uses pantry staples, and works for beginners (no fancy tools needed). I’ve included **key pro tips** to avoid common mistakes.
#
# ---
#
# ### 🍫 **Rich Chocolate Cake**
# *(Serves 8–10; 10–12 minutes prep, 35–40 mins bake)*
# **Total time**: ~50 mins (plus cooling)
#
# #### 🥣 **Ingredients**
# *(Serves 8–10)*
# - **2 cups (250g) all-purpose flour**
# - **1½ cups (300g) granulated sugar**
# - **¾ cup (150g) unsweetened cocoa powder** *(use Dutch-process for best flavor)*
# - **1½ tsp baking soda**
# - **1 tsp baking powder**
# - **1 tsp salt**
# - **1 cup (240ml) buttermilk** *(or 1 cup milk + 1 tbsp vinegar)*
# - **1 cup (240ml) vegetable oil** *(or melted shortening)*
# - **2 large eggs**, room temp
# - **1 tsp vanilla extract**
# - **1½ cups (360ml) hot water** *(key for moistness!)*
#
# #### 🧁 **For the Cake**
# *(Mix all ingredients together)*
# 1. **Preheat oven** to 350°F (175°C).
# 2. **Grease a 9x13-inch pan** or line with parchment paper.
# 3. **Mix dry ingredients**: Whisk flour, sugar, cocoa powder, baking soda, baking powder, and salt in a bowl.
# 4. **Mix wet ingredients**: Beat eggs and vanilla in a large bowl. Add hot water, oil, and buttermilk.
# 5. **Combine**: Add dry ingredients to wet, stirring until just combined (do **not** overmix—this causes toughness).
# 6. **Bake**: Pour batter into pan. Bake **35–40 mins** until a toothpick comes out clean.
# 7. **Cool**: Let cake rest **15 mins** before cutting.
#
# ---
#
# ### ✨ **Pro Tips for Success**
# 1. **Hot water trick**: Adding hot water (not cold!) activates the cocoa powder and makes the cake **moist**. *Skip this, and your cake will dry out.*
# 2. **Room-temp ingredients**: Cold butter/sugar makes a tough cake. Let all ingredients rest at room temp for 15 mins.
# 3. **Don’t overmix**: Mix until just combined—overmixing develops gluten, making the cake tough.
# 4. **Don’t open the oven**: Avoid checking until 10 mins before done (you’ll ruin the cake).
# 5. **Cool on a wire rack**: Prevents sogginess and makes slicing easy.
#
# ---
#
# ### 🌟 **Why This Works**
# - **Cocoa powder** adds depth without bitterness (use Dutch-process for a smooth flavor).
# - **Buttermilk** tenderizes the cake (it’s the secret to a soft crumb).
# - **No flourless version**: This recipe uses **all-purpose flour**—ideal for beginners.
#
# ---
#
# ### 📝 **Optional Swaps**
# - **Vegan**: Replace oil with coconut oil + use buttermilk made from soy milk + vinegar.
# - **Gluten-free**: Use 1:1 gluten-free flour blend.
# - **Frosting**: Add 2 tbsp cocoa powder to the batter for a deeper chocolate flavor.
#
# ---
#
# ### 🥄 **Serving Suggestion**
# Serve with **creamy vanilla frosting** (made with butter, powdered sugar, and vanilla) or **fresh berries**. For a decadent touch, try **chocolate ganache** on top.
#
# > “**The best chocolate cake is always the one you make with love.**” — *Pro Tip: Add 1 tsp of espresso powder to the dry ingredients for an extra deep chocolate flavor!*
#
# Let me know how it turns out—happy baking! 🎂✨

# %% [markdown]
# ### Continuning the chat
#
# To make a chat application that keeps memory of the previous chats, we can append the generated `AIMessage` to the list of messages that we started with and then append new `HumanMessage`s after that. While this provides the full context to the LLM, after some messages the context is going to become so large that it will not fit the LLM. Additional steps will need to be made (e.g., summarization of previous chats, among others), but those are beyond the scope of this tutorial.

# %%
# Append the response to the messages list
messages.append(response)

# Get a new message from the user
new_human_message = HumanMessage(content="I would like a vegan version.")

messages.append(new_human_message)

# Invoke the model with the updated messages
response = chat_model.invoke(messages)

# %%
print(response.content)
# Out:
# Absolutely! Here's a **perfectly moist, rich vegan chocolate cake** that’s *just as delicious* as the original—no dairy, eggs, or animal products. I’ve optimized it for **flourless texture** (no added flour), **deep chocolate flavor**, and **easy vegan substitutions** (even if you’re new to baking). This recipe works for **all-vegan** diets and **gluten-free** if you use a gluten-free flour blend (though it’s not necessary here).
#
# ---
#
# ### 🌱 **Vegan Chocolate Cake (No Eggs, No Dairy, No Animal Products!)**
# *(Serves 8–10; 10 mins prep, 35–40 mins bake)*
# **Total time**: ~50 mins (plus cooling)
#
# #### 🥣 **Ingredients**
# *(Serves 8–10)*
# - **2 cups (250g) all-purpose flour** (or 1:1 gluten-free flour blend)
# - **1.5 cups (300g) granulated sugar**
# - **¾ cup (150g) unsweetened cocoa powder** *(Dutch-process for best flavor)*
# - **1.5 tsp baking soda**
# - **1 tsp baking powder**
# - **1 tsp salt**
# - **1 cup (240ml) unsweetened soy milk** *(or almond milk)*
# - **1 tbsp white vinegar** *(or lemon juice)*
# - **1 cup (240ml) vegetable oil** *(or melted coconut oil)*
# - **2 tbsp ground flaxseed** *(or chia seeds)* + **6 tbsp water**
# - **2 large eggs** *(replaced with flaxseed mixture)*
# - **1 tsp vanilla extract**
# - **1.5 cups (360ml) hot water** *(key for moisture!)*
#
# #### 🍰 **For the Cake**
# *(Mix all ingredients together)*
# 1. **Preheat oven** to 350°F (175°C).
# 2. **Grease a 9x13-inch pan** or line with parchment paper.
# 3. **Mix dry ingredients**: Whisk flour, sugar, cocoa powder, baking soda, baking powder, and salt in a bowl.
# 4. **Make flax "eggs"**: In a separate bowl, mix 2 tbsp ground flaxseed + 6 tbsp water. Let sit **5–10 mins** until thick and gel-like (this replaces eggs).
# 5. **Make buttermilk substitute**: Whisk soy milk + vinegar until curdled (5–10 mins).
# 6. **Mix wet ingredients**: Beat flax mixture, vegetable oil, curdled buttermilk, and vanilla in a large bowl.
# 7. **Combine**: Add dry ingredients to wet, stirring until just combined (do **not** overmix—this causes toughness).
# 8. **Add hot water**: Stir in hot water (this activates the cocoa and keeps it moist).
# 9. **Bake**: Pour batter into pan. Bake **35–40 mins** until a toothpick comes out clean.
# 10. **Cool**: Let cake rest **15 mins** before cutting.
#
# ---
#
# ### ✨ **Pro Tips for Success**
# 1. **Flaxseed "eggs" are KEY**:
#    - Use **ground flaxseed** (not flax seeds) for the right texture.
#    - Let it sit **5–10 mins** to thicken—it’s not a "magic trick," but skipping it = tough cake.
# 2. **Buttermilk substitute**:
#    - **Soy milk + vinegar** works best (almond milk is okay too).
#    - **Do not skip the curdling time**—it activates the baking soda for rise.
# 3. **Hot water is non-negotiable**:
#    - **No cold water**! It makes the cake dry and crumbly.
# 4. **Don’t overmix**:
#    - Stir until *just combined*—overmixing = tough, dense cake.
# 5. **Cool on a wire rack**:
#    - Prevents sogginess and makes slicing easy.
#
# ---
#
# ### 🌟 **Why This Works**
# - **Flaxseed** binds the batter, adds moisture, and mimics eggs without animal products.
# - **Soy milk + vinegar** tenderizes the cake (like buttermilk does in non-vegan recipes).
# - **No flourless version**: Uses **all-purpose flour**—ideal for beginners (and gluten-free if you want).
#
# ---
#
# ### 📝 **Optional Swaps**
# - **Vegan butter**: Replace oil with melted coconut oil or vegan butter (like Miyoko’s).
# - **Frosting**: Try **coconut cream frosting** (1 cup coconut cream + 3 cups powdered sugar + 1 tsp vanilla) or **chocolate ganache** (1 cup coconut milk + 1 cup dark chocolate chips, melted).
# - **Flavor boost**: Add **1 tsp espresso powder** to dry ingredients for extra depth.
#
# ---
#
# ### 🥄 **Serving Suggestion**
# Serve with **fresh berries** or a **creamy coconut frosting**. For a decadent touch, top with **chocolate shavings** or **cinnamon sugar**.
#
# ---
#
# ### 🔥 **Common Mistakes to Avoid**
# - **Using cold water**: Always use **hot water** (it activates the cocoa and keeps the cake moist).
# - **Skipping the flax "eggs"**: This is the #1 reason vegan cakes fail—don’t skip it!
# - **Overmixing**: Stir until *just combined*—any extra stirring = tough cake.
#
# This cake is **moist, rich, and foolproof**—perfect for your vegan baking adventures. Let me know how it turns out! 🌱

# %% [markdown]
# ### Invocation with dictionaries
#
# Except from LangChain messages, dictionaries can be used. Dictionaries have to be in the OpenAI chat completions format. These offer more flexibility with specific types of data, but are not well-suited for all models. For more information, please see:
#
# https://platform.openai.com/docs/api-reference/chat/create

# %%
messages = [
    {"role": "system", "content": "You are a poetry expert"},
    {"role": "user", "content": "Write a haiku about spring"},
    {"role": "assistant", "content": "Cherry blossoms bloom..."}
]
response = chat_model.invoke(messages)

# %%
print(response.content)
# Out:
#
# Warm sun melts winter's last frost,
# New life stirs in soil.
#
# *Note: This haiku follows the traditional 5-7-5 syllable structure and captures the essence of spring through imagery of blooming cherry blossoms, the gentle warmth of the sun, and the renewal of life in the earth. The third line extends the theme with the quiet promise of growth and rebirth.*

# %% [markdown]
# ## Streaming
#
# All the above can be done using streamint, i.e., receiving each next word as it is generated by the model. In contrast to `invoke`, we now need to use the `stream` function of the model which returns an iterator.
#
# For more information on streaming please see:
#
# https://docs.langchain.com/oss/python/langchain/models#stream

# %%
# We start again with system and human messages
system_message = SystemMessage(content="You are a helpful assistant that provides cooking tips.")
human_message = HumanMessage(content="Can you suggest a recipe for chocolate cake?")

messages = [system_message, human_message]

# To keep the final response, we need to keep all the generated chunks as they stream in
full = None

for chunk in chat_model.stream(messages):
    print(chunk.text, end="|", flush=True)
    full = chunk if full is None else full + chunk
# Out:
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||Absolutely|!| Here|'s| a| **|classic|,| moist|,| and| fool|proof| chocolate| cake| recipe|**| that|’s| perfect| for| beginners| and| b|akers| of| all| levels|.| This| recipe| uses| simple| ingredients| and| avoids| common| pitfalls| (|like| over|mix|ing| or| under|b|aking|),| so| you|’ll| get| a| tender|,| rich| cake| every| time|.|
#
# ---|
#
# ###| 🍰| **|Chocolate| Cake|**|
# *S|erves| 8|–|1|0| || Prep|:| 2|0| mins| || Bake|:| 3|5| mins| || Total|:| ~|1| hour| 1|5| mins|*|
#
# ####| 📋| **|Ingredients|**|
# *(|All| measurements| are| for| a| standard| 8|-inch| round| pan|)*|
#
# -| **|Dry| Ingredients|**|
#   -| 2| cups| (|2|5|0|g|)| all|-purpose| flour|
#   -| 1|½| tsp| baking| powder|
#   -| ½| tsp| salt|
#   -| 1|½| cups| (|1|5|0|g|)| Dutch|-|processed| cocoa| powder| *(|use| high|-quality|,| uns|weet|ened| cocoa| for| best| flavor|)*|
#   -| 1| tsp| vanilla| extract|
#
# -| **|W|et| Ingredients|**|
#   -| 1| cup| (|2|4|0|ml|)| but|term|ilk| *(|or| substitute|:| 1| cup| milk| +| 1| tbsp| vinegar|,| let| sit| 5| mins|)*|
#   -| 1| cup| (|2|4|0|ml|)| gran|ulated| sugar|
#   -| 1| cup| (|2|4|0|ml|)| vegetable| oil| *(|or| melted| butter|)*|
#   -| 2| large| eggs|,| room| temperature|
#   -| 1| tsp| vanilla| extract|
#
# -| **|Optional| Frost|ing|**| (|for| serving|)|
#   -| 1| cup| (|2|4|0|ml|)| heavy| cream| +| 1| tbsp| sugar| (|for| whipped| cream|)|
#   -| 1| cup| (|2|4|0|ml|)| chocolate| frosting| (|store|-b|ought| or| homemade|)|
#
# ---|
#
# ###| 🥣| **|Step|-by|-|Step| Instructions|**|
#
# ####| **|1|.| Pre|heat| &| Prep|**|
# -| Pre|heat| oven| to| **|3|5|0|°F| (|1|7|5|°C|)**|.|
# -| Gre|ase| an| 8|-inch| round| cake| pan| with| butter| or| non|-st|ick| spray|.|
# -| Line| the| bottom| with| parchment| paper| for| easy| removal|.|
#
# ####| **|2|.| Mix| Dry| Ingredients|**|
# -| In| a| large| bowl|,| whisk| together| flour|,| baking| powder|,| salt|,| cocoa| powder|,| and| vanilla| extract|.|
# -| *|Tip|:| Don|’t| skip| this| step|—|c|ocoa| powder| and| baking| powder| react| when| mixed|,| so| use| a| whisk| or| hand| mixer| to| avoid| l|umps|.*|
#
# ####| **|3|.| Mix| Wet| Ingredients|**|
# -| In| another| bowl|,| combine| but|term|ilk|,| sugar|,| vegetable| oil|,| eggs|,| and| vanilla|.|
# -| Beat| with| a| hand| mixer| for| 2| minutes| until| smooth| (|no| l|umps|!).|
#
# ####| **|4|.| Combine| Wet| &| Dry|**|
# -| Pour| wet| ingredients| into| the| dry| bowl|.|
# -| **|G|ently| fold|**| with| a| spat|ula| until| just| combined| (|do| NOT| over|mix|—|this| causes| toughness|!).|
# -| *|Pro| tip|:| If| the| batter| is| too| thick|,| add| a| splash| of| but|term|ilk| to| loosen| it|.*|
#
# ####| **|5|.| Bake|**|
# -| Pour| batter| into| the| prepared| pan|.|
# -| Bake| for| **|3|5|–|4|0| minutes|**| until|:|
#   -| A| tooth|pick| inserted| comes| out| clean|.|
#   -| The| cake| springs| back| when| touched|.|
# -| *|Cool| 1|0| minutes| before| removing| from| pan|.*|
#
# ####| **|6|.| Cool| &| Serve|**|
# -| Cool| completely| on| a| wire| rack| (|about| 1| hour|).|
# -| Frost| with| chocolate| frosting| (|or| whipped| cream|)| and| add| berries| or| chocolate| sh|avings| for| extra| flair|.|
#
# ---|
#
# ###| ✨| **|Key| Tips| for| Success|**|
# -| **|But|term|ilk| is| essential|**:| It| adds| moisture| and| tender| texture|.| If| you| don|’t| have| it|,| use| 1| cup| milk| +| 1| tbsp| vinegar| (|or| lemon| juice|).|
# -| **|Room| temperature| ingredients|**:| Eggs| and| butter|/o|il| must| be| at| room| temperature| for| even| texture|.|
# -| **|Don|’t| over|mix|**:| Over|mix|ing| causes| gluten| development|,| making| the| cake| tough|.|
# -| **|Cool|ing| is| crucial|**:| Skipping| this| step| leads| to| a| sog|gy| or| cr|umb|ly| cake|.|
# -| **|F|rost|ing| tip|**:| Use| a| silicone| spat|ula| to| spread| frosting| smoothly|—|no| streak|s|!|
#
# ---|
#
# ###| ❓| **|Common| Questions|**|
# -| **|Why| is| my| cake| dry|?|**|
#   -| Over|b|aking|,| too| little| liquid|,| or| using| old| cocoa| powder| (|c|ocoa| loses| moisture| over| time|).|
# -| **|Why| is| my| cake| dense|?|**|
#   -| Under|b|aking|,| using| too| much| flour|,| or| not| using| room|-temp| butter|.|
# -| **|Can| I| use| substitutes|?|**|
#   -| Yes|!| Replace| oil| with| melted| butter| (|adds| richness|),| or| use| coconut| oil| (|m|ilder| flavor|).|
#
# ---|
#
# This| recipe| is| a| crowd|-|ple|aser| for| any| occasion|—|birthday|,| dessert|,| or| just| because|!| 🎂| Let| me| know| if| you|’d| like| a| **|ch|ocolate| frosting| recipe|**| to| go| with| it|,| or| if| you| need| a| **|ve|gan| version|**| (|just| swap| dairy| for| plant|-based| milk| and| butter|).| Happy| baking|!| 😊|||

# %%
# The response is now an AIMessageChunk object
print(type(full))

# And we can print the content of the response
print(full.content_blocks)
# Out:
# <class 'langchain_core.messages.ai.AIMessageChunk'>
# [{'type': 'text', 'text': "Absolutely! Here's a **classic, moist, and foolproof chocolate cake recipe** that’s perfect for beginners and bakers of all levels. This recipe uses simple ingredients and avoids common pitfalls (like overmixing or underbaking), so you’ll get a tender, rich cake every time.  \n\n---\n\n### 🍰 **Chocolate Cake**  \n*Serves 8–10 | Prep: 20 mins | Bake: 35 mins | Total: ~1 hour 15 mins*  \n\n#### 📋 **Ingredients**  \n*(All measurements are for a standard 8-inch round pan)*  \n\n- **Dry Ingredients**  \n  - 2 cups (250g) all-purpose flour  \n  - 1½ tsp baking powder  \n  - ½ tsp salt  \n  - 1½ cups (150g) Dutch-processed cocoa powder *(use high-quality, unsweetened cocoa for best flavor)*  \n  - 1 tsp vanilla extract  \n\n- **Wet Ingredients**  \n  - 1 cup (240ml) buttermilk *(or substitute: 1 cup milk + 1 tbsp vinegar, let sit 5 mins)*  \n  - 1 cup (240ml) granulated sugar  \n  - 1 cup (240ml) vegetable oil *(or melted butter)*  \n  - 2 large eggs, room temperature  \n  - 1 tsp vanilla extract  \n\n- **Optional Frosting** (for serving)  \n  - 1 cup (240ml) heavy cream + 1 tbsp sugar (for whipped cream)  \n  - 1 cup (240ml) chocolate frosting (store-bought or homemade)  \n\n---\n\n### 🥣 **Step-by-Step Instructions**  \n\n#### **1. Preheat & Prep**  \n- Preheat oven to **350°F (175°C)**.  \n- Grease an 8-inch round cake pan with butter or non-stick spray.  \n- Line the bottom with parchment paper for easy removal.  \n\n#### **2. Mix Dry Ingredients**  \n- In a large bowl, whisk together flour, baking powder, salt, cocoa powder, and vanilla extract.  \n- *Tip: Don’t skip this step—cocoa powder and baking powder react when mixed, so use a whisk or hand mixer to avoid lumps.*  \n\n#### **3. Mix Wet Ingredients**  \n- In another bowl, combine buttermilk, sugar, vegetable oil, eggs, and vanilla.  \n- Beat with a hand mixer for 2 minutes until smooth (no lumps!).  \n\n#### **4. Combine Wet & Dry**  \n- Pour wet ingredients into the dry bowl.  \n- **Gently fold** with a spatula until just combined (do NOT overmix—this causes toughness!).  \n- *Pro tip: If the batter is too thick, add a splash of buttermilk to loosen it.*  \n\n#### **5. Bake**  \n- Pour batter into the prepared pan.  \n- Bake for **35–40 minutes** until:  \n  - A toothpick inserted comes out clean.  \n  - The cake springs back when touched.  \n- *Cool 10 minutes before removing from pan.*  \n\n#### **6. Cool & Serve**  \n- Cool completely on a wire rack (about 1 hour).  \n- Frost with chocolate frosting (or whipped cream) and add berries or chocolate shavings for extra flair.  \n\n---\n\n### ✨ **Key Tips for Success**  \n- **Buttermilk is essential**: It adds moisture and tender texture. If you don’t have it, use 1 cup milk + 1 tbsp vinegar (or lemon juice).  \n- **Room temperature ingredients**: Eggs and butter/oil must be at room temperature for even texture.  \n- **Don’t overmix**: Overmixing causes gluten development, making the cake tough.  \n- **Cooling is crucial**: Skipping this step leads to a soggy or crumbly cake.  \n- **Frosting tip**: Use a silicone spatula to spread frosting smoothly—no streaks!  \n\n---\n\n### ❓ **Common Questions**  \n- **Why is my cake dry?**  \n  - Overbaking, too little liquid, or using old cocoa powder (cocoa loses moisture over time).  \n- **Why is my cake dense?**  \n  - Underbaking, using too much flour, or not using room-temp butter.  \n- **Can I use substitutes?**  \n  - Yes! Replace oil with melted butter (adds richness), or use coconut oil (milder flavor).  \n\n---\n\nThis recipe is a crowd-pleaser for any occasion—birthday, dessert, or just because! 🎂 Let me know if you’d like a **chocolate frosting recipe** to go with it, or if you need a **vegan version** (just swap dairy for plant-based milk and butter). Happy baking! 😊"}]
