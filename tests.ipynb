# %%
# import requests
# from dotenv import load_dotenv
# import os
# import pickle

# load_dotenv()

# API_KEY = os.getenv("SEPAPI_API_KEY")

# params = {
#     "engine": "google_maps",
#     "q": "Traditional Greek Restaurant",
#     "ll": "@35.363366,24.476021, 14z",  # Somewhere in Rethymno, Greece
#     "type": "search",
#     "api_key": API_KEY
# }

# response = requests.get("https://serpapi.com/search", params=params)
# response.raise_for_status()

# restaurants = response.json()

# for place in restaurants.get("local_results", [])[:5]:
#     print(place.get("title"))
#     print("Address:", place.get("address"))
#     print("Rating:", place.get("rating"))
#     print("Coordinates:", place.get("gps_coordinates"))
#     print("-" * 40)

# with open('data/restaurants.pickle', 'wb') as handle:
#     pickle.dump(restaurants, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Othonas taverna
# Address: Mavrokordatou Alexanrou 27, Rethymno 741 31, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.369527, 'longitude': 24.4746158}
# ----------------------------------------
# Taverna Yiannis!!! Greek traditional food, fresh fish, fresh meat and pasta!!!
# Address: Leof. Machis Kritis 159, Rethymno 741 00, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.3684806, 'longitude': 24.531903699999997}
# ----------------------------------------
# VATANIA Taverna meze bar
# Address: Ari Velouchioti 56, Rethymno 741 33, Greece
# Rating: 4.7
# Coordinates: {'latitude': 35.3682012, 'longitude': 24.5044242}
# ----------------------------------------
# Ovelos - Skewer House
# Address: Παντελή Πρεβελάκη 3, Rethymno 741 31, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.3685331, 'longitude': 24.4702803}
# ----------------------------------------
# Armonikon
# Address: Gerakari 120, Rethymno 741 31, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.366437499999996, 'longitude': 24.4777857}
# ----------------------------------------

# %%
# params = {
#     "engine": "google_maps",
#     "q": "Museum or Archaeological Site",
#     "ll": "@35.363366,24.476021, 14z",  # Somewhere in Rethymno, Greece
#     "type": "search",
#     "api_key": API_KEY
# }

# response = requests.get("https://serpapi.com/search", params=params)
# response.raise_for_status()

# museums = response.json()

# for place in museums.get("local_results", [])[:5]:
#     print(place.get("title"))
#     print("Address:", place.get("address"))
#     print("Rating:", place.get("rating"))
#     print("Coordinates:", place.get("gps_coordinates"))
#     print("-" * 40)

# with open('data/museums.pickle', 'wb') as handle:
#     pickle.dump(museums, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Archaeological Museum of Rethymnon
# Address: Αγ. Φραγκίσκου, Rethymno 741 31, Greece
# Rating: 4.4
# Coordinates: {'latitude': 35.3684268, 'longitude': 24.474361299999998}
# ----------------------------------------
# Eleutherna Archaeological Museum
# Address: Epar.Od. Aggelianon-Elefthernas 123, Eleftherna 740 52, Greece
# Rating: 4.6
# Coordinates: {'latitude': 35.3240948, 'longitude': 24.6705675}
# ----------------------------------------
# Heraklion Archaeological Museum
# Address: Ξανθουδίδη και, Chatzidaki 1, Iraklio 712 02, Greece
# Rating: 4.7
# Coordinates: {'latitude': 35.3389825, 'longitude': 25.1371419}
# ----------------------------------------
# Archaeological Museum of Chania | Αρχαιολογικό Μουσείο Χανίων
# Address: Skra 15, Chania 731 33, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.5167648, 'longitude': 24.03772}
# ----------------------------------------
# Ecclesiastical Museum
# Address: Pl. Mitropoleos, Rethimno 741 31, Greece
# Rating: 4.4
# Coordinates: {'latitude': 35.3672895, 'longitude': 24.4761164}
# ----------------------------------------

# %%
# params = {
#     "engine": "google_maps",
#     "q": "Adventure or sports activity",
#     "ll": "@35.363366,24.476021, 14z",  # Somewhere in Rethymno, Greece
#     "type": "search",
#     "api_key": API_KEY
# }

# response = requests.get("https://serpapi.com/search", params=params)
# response.raise_for_status()

# sports = response.json()

# for place in sports.get("local_results", [])[:5]:
#     print(place.get("title"))
#     print("Address:", place.get("address"))
#     print("Rating:", place.get("rating"))
#     print("Coordinates:", place.get("gps_coordinates"))
#     print("-" * 40)

# with open('data/sports.pickle', 'wb') as handle:
#     pickle.dump(sports, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Escape in Action Canyoning
# Address: Ανθυπολοχαγού Ψυχουντάκη, Rethymno 741 32, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.365245, 'longitude': 24.4679559}
# ----------------------------------------
# B.O.A - Base Outdoor Activities Creta
# Address: Kriari 11, Rethymno 741 32, Greece
# Rating: 5
# Coordinates: {'latitude': 35.3651791, 'longitude': 24.4703849}
# ----------------------------------------
# Popeye Watersports
# Address: Σοφοκλή Βενιζέλου 62, Άρη Βελουχιώτη 64, Rethymno 741 33, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.366802199999995, 'longitude': 24.4889907}
# ----------------------------------------
# Watersports Center
# Address: 9HH6+6J, Pigianos Kampos 741 50, Greece
# Rating: 4.1
# Coordinates: {'latitude': 35.3780129, 'longitude': 24.561605999999998}
# ----------------------------------------
# Safari Speedboat Tours
# Address: Sofokli Venizelou 4, Rethymno 741 00, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.3666228, 'longitude': 24.481198799999998}
# ----------------------------------------

# %%
import pickle

with open('data/restaurants.pickle', 'rb') as handle:
    restaurants = pickle.load(handle)
with open('data/museums.pickle', 'rb') as handle:
    museums = pickle.load(handle)
with open('data/sports.pickle', 'rb') as handle:
    sports = pickle.load(handle)

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    return R * c

# %%
# user location
user_lat = 35.363366
user_lon = 24.476021

# %%
print(restaurants['local_results'][0].keys())
# Out:
# dict_keys(['position', 'title', 'place_id', 'data_id', 'data_cid', 'reviews_link', 'photos_link', 'gps_coordinates', 'place_id_search', 'provider_id', 'rating', 'reviews', 'price', 'type', 'types', 'type_id', 'type_ids', 'address', 'open_state', 'hours', 'operating_hours', 'phone', 'website', 'extensions', 'unsupported_extensions', 'service_options', 'user_review', 'thumbnail', 'serpapi_thumbnail'])

# %%
for place in restaurants.get("local_results", [])[:5]:
    print(place.get("title"))
    print("Address:", place.get("address"))
    print("Rating:", place.get("rating"))
    print("Coordinates:", place.get("gps_coordinates"))
    print("Distance (km):", haversine(
        user_lat, user_lon,
        place.get("gps_coordinates", {}).get("latitude"),
        place.get("gps_coordinates", {}).get("longitude")
    ))
    print("Price:", place.get("price"))
    print("Open/closed:", place.get("open_state"))
    print("Operating hours:", place.get("operating_hours"))
    print("service_options:", place.get("service_options"))
    print("-" * 40)
# Out:
# Othonas taverna
# Address: Mavrokordatou Alexanrou 27, Rethymno 741 31, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.369527, 'longitude': 24.4746158}
# Distance (km): 0.6968205034160434
# Price: €10–20
# Open/closed: Open · Closes 12:55 AM
# Operating hours: {'monday': '11\u202fAM–12:55\u202fAM', 'tuesday': '11\u202fAM–12:55\u202fAM', 'wednesday': '11\u202fAM–12:55\u202fAM', 'thursday': '11\u202fAM–12:55\u202fAM', 'friday': '11\u202fAM–12:55\u202fAM', 'saturday': '11\u202fAM–12:55\u202fAM', 'sunday': '11\u202fAM–11:30\u202fPM'}
# service_options: {'dine_in': True, 'curbside_pickup': True, 'delivery': False}
# ----------------------------------------
# Taverna Yiannis!!! Greek traditional food, fresh fish, fresh meat and pasta!!!
# Address: Leof. Machis Kritis 159, Rethymno 741 00, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.3684806, 'longitude': 24.531903699999997}
# Distance (km): 5.099055164092606
# Price: €10–20
# Open/closed: Open · Closes 11 PM
# Operating hours: {'monday': '11\u202fAM–11\u202fPM', 'tuesday': '11\u202fAM–11\u202fPM', 'wednesday': '11\u202fAM–11\u202fPM', 'thursday': '11\u202fAM–11\u202fPM', 'friday': '11\u202fAM–11\u202fPM', 'saturday': '11\u202fAM–11\u202fPM', 'sunday': '12–11\u202fPM'}
# service_options: {'dine_in': True, 'curbside_pickup': True, 'delivery': False}
# ----------------------------------------
# VATANIA Taverna meze bar
# Address: Ari Velouchioti 56, Rethymno 741 33, Greece
# Rating: 4.7
# Coordinates: {'latitude': 35.3682012, 'longitude': 24.5044242}
# Distance (km): 2.6310236530379596
# Price: $$
# Open/closed: Open · Closes 11:45 PM
# Operating hours: {'monday': '9\u202fAM–11:45\u202fPM', 'tuesday': '9\u202fAM–11:45\u202fPM', 'wednesday': '9\u202fAM–11:45\u202fPM', 'thursday': '9\u202fAM–11:45\u202fPM', 'friday': '9\u202fAM–11:45\u202fPM', 'saturday': '9\u202fAM–11:45\u202fPM', 'sunday': '9\u202fAM–11:45\u202fPM'}
# service_options: {'dine_in': True, 'drive_through': True, 'no_contact_delivery': True}
# ----------------------------------------
# Ovelos - Skewer House
# Address: Παντελή Πρεβελάκη 3, Rethymno 741 31, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.3685331, 'longitude': 24.4702803}
# Distance (km): 0.7752945156382545
# Price: €20–25
# Open/closed: Open · Closes 11 PM
# Operating hours: {'monday': '1–11\u202fPM', 'tuesday': '1–11\u202fPM', 'wednesday': '1–11\u202fPM', 'thursday': '1–11\u202fPM', 'friday': '1–11\u202fPM', 'saturday': '1–11\u202fPM', 'sunday': '1–11\u202fPM'}
# service_options: {'dine_in': True, 'takeout': True}
# ----------------------------------------
# Armonikon
# Address: Gerakari 120, Rethymno 741 31, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.366437499999996, 'longitude': 24.4777857}
# Distance (km): 0.37716344105197497
# Price: €5–15
# Open/closed: Closed · Opens 11:30 AM Tue
# Operating hours: {'monday': '11:30\u202fAM–5\u202fPM', 'tuesday': '11:30\u202fAM–5\u202fPM', 'wednesday': '11:30\u202fAM–5\u202fPM', 'thursday': '11:30\u202fAM–5\u202fPM', 'friday': '11:30\u202fAM–5\u202fPM', 'saturday': '11:30\u202fAM–5\u202fPM', 'sunday': 'Closed'}
# service_options: {'dine_in': True, 'takeout': True, 'delivery': False}
# ----------------------------------------

# %%
for place in museums.get("local_results", [])[:5]:
    print(place.get("title"))
    print("Address:", place.get("address"))
    print("Rating:", place.get("rating"))
    print("Coordinates:", place.get("gps_coordinates"))
    print("Distance (km):", haversine(
        user_lat, user_lon,
        place.get("gps_coordinates", {}).get("latitude"),
        place.get("gps_coordinates", {}).get("longitude")
    ))
    print("Price:", place.get("price"))
    print("Open/closed:", place.get("open_state"))
    print("Operating hours:", place.get("operating_hours"))
    print("service_options:", place.get("service_options"))
    print("-" * 40)
# Out:
# Archaeological Museum of Rethymnon
# Address: Αγ. Φραγκίσκου, Rethymno 741 31, Greece
# Rating: 4.4
# Coordinates: {'latitude': 35.3684268, 'longitude': 24.474361299999998}
# Distance (km): 0.5825117443756878
# Price: None
# Open/closed: Closed · Opens 9 AM Wed
# Operating hours: {'monday': '9\u202fAM–5\u202fPM', 'tuesday': 'Closed', 'wednesday': '9\u202fAM–5\u202fPM', 'thursday': '9\u202fAM–5\u202fPM', 'friday': '9\u202fAM–5\u202fPM', 'saturday': '9\u202fAM–5\u202fPM', 'sunday': '9\u202fAM–5\u202fPM'}
# service_options: None
# ----------------------------------------
# Eleutherna Archaeological Museum
# Address: Epar.Od. Aggelianon-Elefthernas 123, Eleftherna 740 52, Greece
# Rating: 4.6
# Coordinates: {'latitude': 35.3240948, 'longitude': 24.6705675}
# Distance (km): 18.17790712853423
# Price: None
# Open/closed: Closed · Opens 8:30 AM Wed
# Operating hours: {'monday': '8:30\u202fAM–3:30\u202fPM', 'tuesday': 'Closed', 'wednesday': '8:30\u202fAM–3:30\u202fPM', 'thursday': '8:30\u202fAM–3:30\u202fPM', 'friday': '8:30\u202fAM–3:30\u202fPM', 'saturday': '8:30\u202fAM–3:30\u202fPM', 'sunday': '8:30\u202fAM–3:30\u202fPM'}
# service_options: None
# ----------------------------------------
# Heraklion Archaeological Museum
# Address: Ξανθουδίδη και, Chatzidaki 1, Iraklio 712 02, Greece
# Rating: 4.7
# Coordinates: {'latitude': 35.3389825, 'longitude': 25.1371419}
# Distance (km): 60.02015255589579
# Price: None
# Open/closed: Closed · Opens 8:30 AM Tue
# Operating hours: {'monday': '8:30\u202fAM–3:30\u202fPM', 'tuesday': '8:30\u202fAM–3:30\u202fPM', 'wednesday': '10\u202fAM–5\u202fPM', 'thursday': '8:30\u202fAM–3:30\u202fPM', 'friday': '8:30\u202fAM–3:30\u202fPM', 'saturday': '8:30\u202fAM–3:30\u202fPM', 'sunday': '8:30\u202fAM–3:30\u202fPM'}
# service_options: {'onsite_services': True}
# ----------------------------------------
# Archaeological Museum of Chania | Αρχαιολογικό Μουσείο Χανίων
# Address: Skra 15, Chania 731 33, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.5167648, 'longitude': 24.03772}
# Distance (km): 43.21560435796335
# Price: None
# Open/closed: Closed · Opens 8:30 AM Wed
# Operating hours: {'monday': '8:30\u202fAM–3:30\u202fPM', 'tuesday': 'Closed', 'wednesday': '8:30\u202fAM–3:30\u202fPM', 'thursday': '8:30\u202fAM–3:30\u202fPM', 'friday': '8:30\u202fAM–3:30\u202fPM', 'saturday': '8:30\u202fAM–3:30\u202fPM', 'sunday': '8:30\u202fAM–3:30\u202fPM'}
# service_options: {'onsite_services': True}
# ----------------------------------------
# Ecclesiastical Museum
# Address: Pl. Mitropoleos, Rethimno 741 31, Greece
# Rating: 4.4
# Coordinates: {'latitude': 35.3672895, 'longitude': 24.4761164}
# Distance (km): 0.4363590498168437
# Price: None
# Open/closed: Closed · Opens 9:30 AM Mon
# Operating hours: {'monday': '9:30\u202fAM–5\u202fPM', 'tuesday': 'Closed', 'wednesday': 'Closed', 'thursday': 'Closed', 'friday': 'Closed', 'saturday': 'Closed', 'sunday': 'Closed'}
# service_options: None
# ----------------------------------------

# %%
for place in sports.get("local_results", [])[:5]:
    print(place.get("title"))
    print("Address:", place.get("address"))
    print("Rating:", place.get("rating"))
    print("Coordinates:", place.get("gps_coordinates"))
    print("Distance (km):", haversine(
        user_lat, user_lon,
        place.get("gps_coordinates", {}).get("latitude"),
        place.get("gps_coordinates", {}).get("longitude")
    ))
    print("Price:", place.get("price"))
    print("Open/closed:", place.get("open_state"))
    print("Operating hours:", place.get("operating_hours"))
    print("service_options:", place.get("service_options"))
    print("-" * 40)
# Out:
# Escape in Action Canyoning
# Address: Ανθυπολοχαγού Ψυχουντάκη, Rethymno 741 32, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.365245, 'longitude': 24.4679559}
# Distance (km): 0.7605889339645273
# Price: None
# Open/closed: Open 24 hours
# Operating hours: {'monday': 'Open 24 hours', 'tuesday': 'Open 24 hours', 'wednesday': 'Open 24 hours', 'thursday': 'Open 24 hours', 'friday': 'Open 24 hours', 'saturday': 'Open 24 hours', 'sunday': 'Open 24 hours'}
# service_options: None
# ----------------------------------------
# B.O.A - Base Outdoor Activities Creta
# Address: Kriari 11, Rethymno 741 32, Greece
# Rating: 5
# Coordinates: {'latitude': 35.3651791, 'longitude': 24.4703849}
# Distance (km): 0.5493994050711971
# Price: None
# Open/closed: Closed · Opens 8 AM Tue
# Operating hours: {'monday': '8\u202fAM–6\u202fPM', 'tuesday': '8\u202fAM–6\u202fPM', 'wednesday': '8\u202fAM–6\u202fPM', 'thursday': '8\u202fAM–6\u202fPM', 'friday': '8\u202fAM–6\u202fPM', 'saturday': '8\u202fAM–6\u202fPM', 'sunday': '8\u202fAM–6\u202fPM'}
# service_options: None
# ----------------------------------------
# Popeye Watersports
# Address: Σοφοκλή Βενιζέλου 62, Άρη Βελουχιώτη 64, Rethymno 741 33, Greece
# Rating: 4.9
# Coordinates: {'latitude': 35.366802199999995, 'longitude': 24.4889907}
# Distance (km): 1.236568865166185
# Price: None
# Open/closed: Open · Closes 8 PM
# Operating hours: {'monday': '9\u202fAM–8\u202fPM', 'tuesday': '9\u202fAM–8\u202fPM', 'wednesday': '9\u202fAM–8\u202fPM', 'thursday': '9\u202fAM–8\u202fPM', 'friday': '9\u202fAM–8\u202fPM', 'saturday': '9\u202fAM–8\u202fPM', 'sunday': '9\u202fAM–8\u202fPM'}
# service_options: None
# ----------------------------------------
# Watersports Center
# Address: 9HH6+6J, Pigianos Kampos 741 50, Greece
# Rating: 4.1
# Coordinates: {'latitude': 35.3780129, 'longitude': 24.561605999999998}
# Distance (km): 7.929145945850135
# Price: None
# Open/closed: Closed · Opens 10 AM Tue
# Operating hours: {'monday': '10\u202fAM–6\u202fPM', 'tuesday': '10\u202fAM–6\u202fPM', 'wednesday': '10\u202fAM–6\u202fPM', 'thursday': '10\u202fAM–6\u202fPM', 'friday': '10\u202fAM–6\u202fPM', 'saturday': '10\u202fAM–6\u202fPM', 'sunday': '10\u202fAM–6\u202fPM'}
# service_options: None
# ----------------------------------------
# Safari Speedboat Tours
# Address: Sofokli Venizelou 4, Rethymno 741 00, Greece
# Rating: 4.8
# Coordinates: {'latitude': 35.3666228, 'longitude': 24.481198799999998}
# Distance (km): 0.5929454389172344
# Price: None
# Open/closed: Open · Closes 11 PM
# Operating hours: {'monday': '9\u202fAM–11\u202fPM', 'tuesday': '9\u202fAM–11\u202fPM', 'wednesday': '9\u202fAM–11\u202fPM', 'thursday': '9\u202fAM–11\u202fPM', 'friday': '9\u202fAM–11\u202fPM', 'saturday': '9\u202fAM–11\u202fPM', 'sunday': '9\u202fAM–11\u202fPM'}
# service_options: None
# ----------------------------------------

# %%
import requests

params = {
    'latitude': user_lat,
    'longitude': user_lon,
    "hourly": [
        "temperature_2m",
        "windspeed_10m",
        "precipitation",
        "precipitation_probability"
    ],
    "forecast_hours": 3,   # next 3 hours only
}

response = requests.get("https://api.open-meteo.com/v1/forecast", params=params)
response.raise_for_status()

weather = response.json()

# %%
print(weather["hourly"])
# Out:
# {'time': ['2026-02-02T16:00', '2026-02-02T17:00', '2026-02-02T18:00'], 'temperature_2m': [14.0, 13.2, 12.6], 'windspeed_10m': [11.7, 8.9, 9.1], 'precipitation': [0.0, 0.0, 0.0], 'precipitation_probability': [55, 15, 0]}
